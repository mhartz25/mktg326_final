# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
import statsmodels.api as sm
import matplotlib.pylab as plt
from sklearn.tree import DecisionTreeRegressor

os.chdir('/Users/matthewhartz/python_practice/projects/mktg_326/data')

# %%
df = pd.read_csv("test1.csv")

df1 = df.iloc[:,[0,1,2,3]]

# %%
##Need to drop all nulls

# %%
df1.head()
# Out:
#             Timestamp What gender do you identify with? How old are you?  \
# 0  7/20/2021 19:42:11                            Female            21-22
# 1  7/30/2021 11:45:40                                              21-22
# 2   8/5/2021 15:52:55                            Female            21-22
# 3   8/5/2021 15:59:45                            Female            21-22
# 4   8/5/2021 16:58:17                            Female            23-24
#
#   Check all social media that you use at least once a week.
# 0     Instagram, TikTok, Snapchat, Facebook, YouTube
# 1     Facebook, Instagram, TikTok, YouTube, LinkedIn
# 2     Facebook, Instagram, TikTok, YouTube, LinkedIn
# 3     Facebook, Instagram, TikTok, YouTube, LinkedIn
# 4                                  Snapchat, YouTube

# %%
##Convert columns to usable numerics
df1 = pd.get_dummies(df1, columns= ['What gender do you identify with?'])

df1.dtypes
# Out:
# Timestamp                                                    object
# How old are you?                                             object
# Check all social media that you use at least once a week.    object
# What gender do you identify with?_                            uint8
# What gender do you identify with?_Female                      uint8
# What gender do you identify with?_Male                        uint8
# What gender do you identify with?_Prefer not to say           uint8
# dtype: object

# %%
social = df1.explode('Check all social media that you use at least once a week.')

social.head()
# Out:
#             Timestamp How old are you?  \
# 0  7/20/2021 19:42:11            21-22
# 1  7/30/2021 11:45:40            21-22
# 2   8/5/2021 15:52:55            21-22
# 3   8/5/2021 15:59:45            21-22
# 4   8/5/2021 16:58:17            23-24
#
#   Check all social media that you use at least once a week.  \
# 0     Instagram, TikTok, Snapchat, Facebook, YouTube
# 1     Facebook, Instagram, TikTok, YouTube, LinkedIn
# 2     Facebook, Instagram, TikTok, YouTube, LinkedIn
# 3     Facebook, Instagram, TikTok, YouTube, LinkedIn
# 4                                  Snapchat, YouTube
#
#    What gender do you identify with?_   \
# 0                                    0
# 1                                    1
# 2                                    0
# 3                                    0
# 4                                    0
#
#    What gender do you identify with?_Female  \
# 0                                         1
# 1                                         0
# ...
